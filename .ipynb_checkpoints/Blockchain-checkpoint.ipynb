# %%
import numpy as np
import matplotlib.pyplot as plt
import statistics

# %%
def plot(data):
    plt.plot(data)
    plt.ylabel('Block delay (ms)')
    plt.xlabel('Block #')
    plt.show()

def stats(data):
    # Total
    print("All blocks")
    print("\tMean: ", statistics.mean(data))
    print("\tMedian: ", statistics.median(data))
    print("\tMax: ", max(data))
    print("\tMin:", min(data))
    
    # First 1000
    print("\nFirst 1000")
    print("\tMean: ", statistics.mean(data[0:500]))
    print("\tMedian: ", statistics.median(data[0:500]))
    
    # Second 1000
    print("\nSecond 1000")
    print("\tMean: ", statistics.mean(data[500:]))
    print("\tMedian: ", statistics.median(data[500:]))

# %%
data12 = np.loadtxt("blockchain/data12.csv", comments="#", delimiter=",", unpack=False)
data16 = np.loadtxt("blockchain/data16.csv", comments="#", delimiter=",", unpack=False)
data20 = np.loadtxt("blockchain/data20.csv", comments="#", delimiter=",", unpack=False)

# %%
plot(data12)
stats(data12)
# Out:
# All blocks
# 	Mean:  1.928
# 	Median:  1.0
# 	Max:  20.0
# 	Min: 0.0
#
# First 1000
# 	Mean:  2.018
# 	Median:  1.0
#
# Second 1000
# 	Mean:  1.898
# 	Median:  1.0

# %%
plot(data16)
stats(data16)
# Out:
# All blocks
# 	Mean:  35.4095
# 	Median:  23.0
# 	Max:  368.0
# 	Min: 0.0
#
# First 1000
# 	Mean:  33.954
# 	Median:  22.0
#
# Second 1000
# 	Mean:  35.894666666666666
# 	Median:  24.0

# %%
plot(data20)
stats(data20)
# Out:
# All blocks
# 	Mean:  572.031
# 	Median:  396.0
# 	Max:  4490.0
# 	Min: 0.0
#
# First 1000
# 	Mean:  545.282
# 	Median:  400.5
#
# Second 1000
# 	Mean:  580.9473333333333
# 	Median:  394.0
